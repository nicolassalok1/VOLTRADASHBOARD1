# %% [markdown]
# ## Note au jury — algotrading RL (jeu de prédiction)
#
# Notebook axé sur l'apprentissage par renforcement pour un jeu de trading directionnel. Les cellules de code sont intactes ; les notes explicitent la logique MDP, les choix de modèle et les limites expérimentales.

# %% [markdown]
# # Reinforcement Learning for Finance — Chapitre 06 : Trading DQL
#
# Objectif : entraîner un agent à prendre des positions long/short/flat sur un actif simulé (GBM) en maximisant le PnL ajusté du risque. La formulation DQN repose sur : état (prix/retours, features techniques, temps), actions discrètes, récompense = PnL net de coûts. La section détaille la génération de trajectoires, l'architecture réseau et la boucle d'entraînement/évaluation.

# %% [markdown]
# ## Cadre du jeu de prédiction
#
# L'agent anticipe la direction du mouvement suivant et ajuste sa position. Points clés :
# - représentation d'état : retours normalisés, indicateurs simples, horodatage relatif ;
# - politique : DQN avec epsilon-greedy pour explorer, cible fixe pour stabiliser ;
# - métriques : PnL cumulé, ratio gain/perte, drawdown, stabilité de la valeur de portefeuille.

# %%
import math
import random
import numpy as np
import pandas as pd
from pylab import plt, mpl
import torch

# %%
plt.style.use('seaborn-v0_8')
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'
np.set_printoptions(suppress=True)

# %%
from finance import *

# %%
from finance import *

# %%
from finance import *

finance = Finance('GLD', 'r', min_accuracy=47.5, n_features=8)
#finance.data[finance.symbol].plot(title=finance.symbol, lw=1.0, c='b');

# %%
from dqlagent_pytorch import *

# %%
random.seed(100)
np.random.seed(100)
torch.manual_seed(100)

# %%
dqlagent = DQLAgent(finance.symbol, finance.feature,
                 finance.n_features, finance, lr=0.0001)

# %%
# %time dqlagent.learn(500)
# Out:
# episode=   1 | treward=  4.000 | max=  4.000
# episode=   2 | treward=  6.000 | max=  6.000
# episode=   3 | treward=  4.000 | max=  6.000
# episode=   4 | treward=  3.000 | max=  6.000
# episode=   5 | treward=  4.000 | max=  6.000
# episode=   6 | treward=  0.000 | max=  6.000
# episode=   7 | treward=  6.000 | max=  6.000
# episode=   8 | treward=  8.000 | max=  8.000
# episode=   9 | treward=  3.000 | max=  8.000
# episode=  10 | treward=  3.000 | max=  8.000
# episode=  11 | treward=  4.000 | max=  8.000
# episode=  12 | treward=  3.000 | max=  8.000
# episode=  13 | treward=  5.000 | max=  8.000
# episode=  14 | treward=  5.000 | max=  8.000
# episode=  15 | treward=  3.000 | max=  8.000
# episode=  16 | treward=  3.000 | max=  8.000
# episode=  17 | treward=  3.000 | max=  8.000
# episode=  18 | treward=  5.000 | max=  8.000
# episode=  19 | treward=  5.000 | max=  8.000
# episode=  20 | treward=  5.000 | max=  8.000
# episode=  21 | treward=  2.000 | max=  8.000
# episode=  22 | treward=  4.000 | max=  8.000
# episode=  23 | treward=  2.000 | max=  8.000
# episode=  24 | treward=  5.000 | max=  8.000
# episode=  25 | treward=  5.000 | max=  8.000
# episode=  26 | treward=  9.000 | max=  9.000
# episode=  27 | treward=  3.000 | max=  9.000
# episode=  28 | treward=  6.000 | max=  9.000
# episode=  29 | treward=  2.000 | max=  9.000
# episode=  30 | treward=  5.000 | max=  9.000
# episode=  31 | treward=  6.000 | max=  9.000
# episode=  32 | treward=  4.000 | max=  9.000
# episode=  33 | treward=  2.000 | max=  9.000
# episode=  34 | treward=  2.000 | max=  9.000
# episode=  35 | treward=  4.000 | max=  9.000
# episode=  36 | treward=  6.000 | max=  9.000
# episode=  37 | treward= 10.000 | max= 10.000
# episode=  38 | treward=  7.000 | max= 10.000
# episode=  39 | treward=  2.000 | max= 10.000
# episode=  40 | treward=  3.000 | max= 10.000
# episode=  41 | treward=  4.000 | max= 10.000
# episode=  42 | treward=  4.000 | max= 10.000
# episode=  43 | treward=  5.000 | max= 10.000
# episode=  44 | treward=  4.000 | max= 10.000
# episode=  45 | treward=  5.000 | max= 10.000
# episode=  46 | treward=  9.000 | max= 10.000
# episode=  47 | treward=  3.000 | max= 10.000
# episode=  48 | treward=  4.000 | max= 10.000
# episode=  49 | treward=  7.000 | max= 10.000
# episode=  50 | treward=  7.000 | max= 10.000
# episode=  51 | treward=  6.000 | max= 10.000
# episode=  52 | treward=  5.000 | max= 10.000
# episode=  53 | treward=  7.000 | max= 10.000
# episode=  54 | treward= 10.000 | max= 10.000
# episode=  55 | treward=  2.000 | max= 10.000
# episode=  56 | treward=  5.000 | max= 10.000
# episode=  57 | treward= 11.000 | max= 11.000
# episode=  58 | treward=  7.000 | max= 11.000
# episode=  59 | treward=  4.000 | max= 11.000
# episode=  60 | treward=  4.000 | max= 11.000
# episode=  61 | treward=  5.000 | max= 11.000
# episode=  62 | treward=  5.000 | max= 11.000
# episode=  63 | treward=  7.000 | max= 11.000
# episode=  64 | treward=  4.000 | max= 11.000
# episode=  65 | treward=  7.000 | max= 11.000
# episode=  66 | treward=  5.000 | max= 11.000
# episode=  67 | treward=  8.000 | max= 11.000
# episode=  68 | treward=  5.000 | max= 11.000
# episode=  69 | treward=  5.000 | max= 11.000
# episode=  70 | treward=  4.000 | max= 11.000
# episode=  71 | treward=  5.000 | max= 11.000
# episode=  72 | treward=  7.000 | max= 11.000
# episode=  73 | treward=  5.000 | max= 11.000
# episode=  74 | treward=  6.000 | max= 11.000
# episode=  75 | treward=  4.000 | max= 11.000
# episode=  76 | treward=  4.000 | max= 11.000
# episode=  77 | treward=  2.000 | max= 11.000
# episode=  78 | treward=  7.000 | max= 11.000
# episode=  79 | treward=  4.000 | max= 11.000
# episode=  80 | treward=  4.000 | max= 11.000
# episode=  81 | treward=  4.000 | max= 11.000
# episode=  82 | treward=  2.000 | max= 11.000
# episode=  83 | treward=  6.000 | max= 11.000
# episode=  84 | treward=  2.000 | max= 11.000
# episode=  85 | treward=  5.000 | max= 11.000
# episode=  86 | treward=  6.000 | max= 11.000
# episode=  87 | treward=  5.000 | max= 11.000
# episode=  88 | treward=  1.000 | max= 11.000
# episode=  89 | treward=  4.000 | max= 11.000
# episode=  90 | treward=  5.000 | max= 11.000
# episode=  91 | treward=  3.000 | max= 11.000
# episode=  92 | treward=  5.000 | max= 11.000
# episode=  93 | treward=  7.000 | max= 11.000
# episode=  94 | treward=  3.000 | max= 11.000
# episode=  95 | treward=  5.000 | max= 11.000
# episode=  96 | treward=  5.000 | max= 11.000
# episode=  97 | treward=  8.000 | max= 11.000
# episode=  98 | treward=  6.000 | max= 11.000
# episode=  99 | treward=  3.000 | max= 11.000
# episode= 100 | treward=  4.000 | max= 11.000
# episode= 101 | treward=  4.000 | max= 11.000
# episode= 102 | treward=  9.000 | max= 11.000
# episode= 103 | treward= 16.000 | max= 16.000
# episode= 104 | treward=  6.000 | max= 16.000
# episode= 105 | treward=  6.000 | max= 16.000
# episode= 106 | treward=  4.000 | max= 16.000
# episode= 107 | treward=  4.000 | max= 16.000
# episode= 108 | treward= 12.000 | max= 16.000
# episode= 109 | treward=  6.000 | max= 16.000
# episode= 110 | treward= 10.000 | max= 16.000
# episode= 111 | treward=  4.000 | max= 16.000
# episode= 112 | treward=  5.000 | max= 16.000
# episode= 113 | treward=  5.000 | max= 16.000
# episode= 114 | treward=  4.000 | max= 16.000
# episode= 115 | treward=  6.000 | max= 16.000
# episode= 116 | treward=  8.000 | max= 16.000
# episode= 117 | treward=  5.000 | max= 16.000
# episode= 118 | treward=  5.000 | max= 16.000
# episode= 119 | treward=  4.000 | max= 16.000
# episode= 120 | treward=  7.000 | max= 16.000
# episode= 121 | treward=  5.000 | max= 16.000
# episode= 122 | treward=  7.000 | max= 16.000
# episode= 123 | treward=  6.000 | max= 16.000
# episode= 124 | treward=  6.000 | max= 16.000
# episode= 125 | treward=  4.000 | max= 16.000
# episode= 126 | treward=  8.000 | max= 16.000
# episode= 127 | treward= 12.000 | max= 16.000
# episode= 128 | treward=  8.000 | max= 16.000
# episode= 129 | treward=  3.000 | max= 16.000
# episode= 130 | treward=  2.000 | max= 16.000
# episode= 131 | treward=  8.000 | max= 16.000
# episode= 132 | treward=  7.000 | max= 16.000
# episode= 133 | treward=  6.000 | max= 16.000
# episode= 134 | treward=  5.000 | max= 16.000
# episode= 135 | treward=  9.000 | max= 16.000
# episode= 136 | treward=  9.000 | max= 16.000
# episode= 137 | treward=  3.000 | max= 16.000
# episode= 138 | treward=  8.000 | max= 16.000
# episode= 139 | treward=  8.000 | max= 16.000
# episode= 140 | treward=  6.000 | max= 16.000
# episode= 141 | treward=  8.000 | max= 16.000
# episode= 142 | treward=  7.000 | max= 16.000
# episode= 143 | treward=  5.000 | max= 16.000
# episode= 144 | treward=  4.000 | max= 16.000
# episode= 145 | treward=  6.000 | max= 16.000
# episode= 146 | treward=  7.000 | max= 16.000
# episode= 147 | treward=  6.000 | max= 16.000
# episode= 148 | treward=  4.000 | max= 16.000
# episode= 149 | treward=  6.000 | max= 16.000
# episode= 150 | treward=  7.000 | max= 16.000
# episode= 151 | treward=  5.000 | max= 16.000
# episode= 152 | treward=  6.000 | max= 16.000
# episode= 153 | treward=  5.000 | max= 16.000
# episode= 154 | treward=  7.000 | max= 16.000
# episode= 155 | treward=  9.000 | max= 16.000
# episode= 156 | treward=  3.000 | max= 16.000
# episode= 157 | treward=  7.000 | max= 16.000
# episode= 158 | treward=  2.000 | max= 16.000
# episode= 159 | treward=  5.000 | max= 16.000
# episode= 160 | treward=  4.000 | max= 16.000
# episode= 161 | treward=  7.000 | max= 16.000
# episode= 162 | treward=  6.000 | max= 16.000
# episode= 163 | treward=  7.000 | max= 16.000
# episode= 164 | treward=  5.000 | max= 16.000
# episode= 165 | treward=  3.000 | max= 16.000
# episode= 166 | treward=  6.000 | max= 16.000
# episode= 167 | treward=  5.000 | max= 16.000
# episode= 168 | treward=  6.000 | max= 16.000
# episode= 169 | treward=  6.000 | max= 16.000
# episode= 170 | treward=  5.000 | max= 16.000
# episode= 171 | treward=  8.000 | max= 16.000
# episode= 172 | treward=  8.000 | max= 16.000
# episode= 173 | treward=  8.000 | max= 16.000
# episode= 174 | treward=  9.000 | max= 16.000
# episode= 175 | treward=  8.000 | max= 16.000
# episode= 176 | treward=  7.000 | max= 16.000
# episode= 177 | treward=  5.000 | max= 16.000
# episode= 178 | treward= 10.000 | max= 16.000
# episode= 179 | treward=  6.000 | max= 16.000
# episode= 180 | treward=  9.000 | max= 16.000
# episode= 181 | treward=  9.000 | max= 16.000
# episode= 182 | treward=  7.000 | max= 16.000
# episode= 183 | treward=  3.000 | max= 16.000
# episode= 184 | treward=  5.000 | max= 16.000
# episode= 185 | treward=  7.000 | max= 16.000
# episode= 186 | treward=  9.000 | max= 16.000
# episode= 187 | treward= 11.000 | max= 16.000
# episode= 188 | treward=  4.000 | max= 16.000
# episode= 189 | treward=  7.000 | max= 16.000
# episode= 190 | treward=  6.000 | max= 16.000
# episode= 191 | treward=  6.000 | max= 16.000
# episode= 192 | treward=  6.000 | max= 16.000
# episode= 193 | treward=  6.000 | max= 16.000
# episode= 194 | treward=  9.000 | max= 16.000
# episode= 195 | treward=  5.000 | max= 16.000
# episode= 196 | treward=  2.000 | max= 16.000
# episode= 197 | treward=  5.000 | max= 16.000
# episode= 198 | treward=  8.000 | max= 16.000
# episode= 199 | treward=  9.000 | max= 16.000
# episode= 200 | treward=  8.000 | max= 16.000
# episode= 201 | treward=  6.000 | max= 16.000
# episode= 202 | treward=  7.000 | max= 16.000
# episode= 203 | treward= 11.000 | max= 16.000
# episode= 204 | treward=  8.000 | max= 16.000
# episode= 205 | treward=  5.000 | max= 16.000
# episode= 206 | treward=  6.000 | max= 16.000
# episode= 207 | treward= 11.000 | max= 16.000
# episode= 208 | treward=  5.000 | max= 16.000
# episode= 209 | treward=  5.000 | max= 16.000
# episode= 210 | treward=  8.000 | max= 16.000
# episode= 211 | treward=  7.000 | max= 16.000
# episode= 212 | treward=  6.000 | max= 16.000
# episode= 213 | treward=  9.000 | max= 16.000
# episode= 214 | treward=  6.000 | max= 16.000
# episode= 215 | treward=  5.000 | max= 16.000
# episode= 216 | treward=  6.000 | max= 16.000
# episode= 217 | treward=  3.000 | max= 16.000
# episode= 218 | treward=  3.000 | max= 16.000
# episode= 219 | treward=  5.000 | max= 16.000
# episode= 220 | treward=  8.000 | max= 16.000
# episode= 221 | treward=  7.000 | max= 16.000
# episode= 222 | treward=  6.000 | max= 16.000
# episode= 223 | treward=  7.000 | max= 16.000
# episode= 224 | treward=  9.000 | max= 16.000
# episode= 225 | treward= 10.000 | max= 16.000
# episode= 226 | treward=  5.000 | max= 16.000
# episode= 227 | treward=  6.000 | max= 16.000
# episode= 228 | treward= 10.000 | max= 16.000
# episode= 229 | treward=  5.000 | max= 16.000
# episode= 230 | treward=  6.000 | max= 16.000
# episode= 231 | treward=  7.000 | max= 16.000
# episode= 232 | treward=  6.000 | max= 16.000
# episode= 233 | treward=  7.000 | max= 16.000
# episode= 234 | treward=  4.000 | max= 16.000
# episode= 235 | treward=  8.000 | max= 16.000
# episode= 236 | treward=  8.000 | max= 16.000
# episode= 237 | treward=  5.000 | max= 16.000
# episode= 238 | treward=  7.000 | max= 16.000
# episode= 239 | treward=  6.000 | max= 16.000
# episode= 240 | treward=  4.000 | max= 16.000
# episode= 241 | treward= 10.000 | max= 16.000
# episode= 242 | treward=  7.000 | max= 16.000
# episode= 243 | treward=  3.000 | max= 16.000
# episode= 244 | treward=  7.000 | max= 16.000
# episode= 245 | treward=  8.000 | max= 16.000
# episode= 246 | treward=  4.000 | max= 16.000
# episode= 247 | treward=  6.000 | max= 16.000
# episode= 248 | treward=  5.000 | max= 16.000
# episode= 249 | treward=  7.000 | max= 16.000
# episode= 250 | treward=  7.000 | max= 16.000
# episode= 251 | treward=  9.000 | max= 16.000
# episode= 252 | treward=  6.000 | max= 16.000
# episode= 253 | treward=  7.000 | max= 16.000
# episode= 254 | treward=  7.000 | max= 16.000
# episode= 255 | treward=  7.000 | max= 16.000
# episode= 256 | treward=  4.000 | max= 16.000
# episode= 257 | treward=  7.000 | max= 16.000
# episode= 258 | treward=  4.000 | max= 16.000
# episode= 259 | treward=  8.000 | max= 16.000
# episode= 260 | treward=  9.000 | max= 16.000
# episode= 261 | treward=  2.000 | max= 16.000
# episode= 262 | treward=  5.000 | max= 16.000
# episode= 263 | treward= 10.000 | max= 16.000
# episode= 264 | treward=  5.000 | max= 16.000
# episode= 265 | treward=  5.000 | max= 16.000
# episode= 266 | treward=  6.000 | max= 16.000
# episode= 267 | treward=  6.000 | max= 16.000
# episode= 268 | treward=  6.000 | max= 16.000
# episode= 269 | treward=  7.000 | max= 16.000
# episode= 270 | treward=  9.000 | max= 16.000
# episode= 271 | treward=  7.000 | max= 16.000
# episode= 272 | treward=  4.000 | max= 16.000
# episode= 273 | treward=  7.000 | max= 16.000
# episode= 274 | treward=  8.000 | max= 16.000
# episode= 275 | treward=  7.000 | max= 16.000
# episode= 276 | treward=  5.000 | max= 16.000
# episode= 277 | treward=  6.000 | max= 16.000
# episode= 278 | treward=  7.000 | max= 16.000
# episode= 279 | treward= 11.000 | max= 16.000
# episode= 280 | treward=  7.000 | max= 16.000
# episode= 281 | treward=  9.000 | max= 16.000
# episode= 282 | treward=  7.000 | max= 16.000
# episode= 283 | treward= 11.000 | max= 16.000
# episode= 284 | treward=  9.000 | max= 16.000
# episode= 285 | treward=  5.000 | max= 16.000
# episode= 286 | treward=  3.000 | max= 16.000
# episode= 287 | treward=  8.000 | max= 16.000
# episode= 288 | treward=  9.000 | max= 16.000
# episode= 289 | treward= 10.000 | max= 16.000
# episode= 290 | treward=  8.000 | max= 16.000
# episode= 291 | treward=  8.000 | max= 16.000
# episode= 292 | treward=  6.000 | max= 16.000
# episode= 293 | treward=  5.000 | max= 16.000
# episode= 294 | treward=  6.000 | max= 16.000
# episode= 295 | treward= 10.000 | max= 16.000
# episode= 296 | treward=  5.000 | max= 16.000
# episode= 297 | treward=  5.000 | max= 16.000
# episode= 298 | treward=  6.000 | max= 16.000
# episode= 299 | treward= 10.000 | max= 16.000
# episode= 300 | treward=  9.000 | max= 16.000
# episode= 301 | treward=  5.000 | max= 16.000
# episode= 302 | treward=  8.000 | max= 16.000
# episode= 303 | treward=  8.000 | max= 16.000
# episode= 304 | treward=  8.000 | max= 16.000
# episode= 305 | treward=  6.000 | max= 16.000
# episode= 306 | treward=  5.000 | max= 16.000
# episode= 307 | treward=  6.000 | max= 16.000
# episode= 308 | treward=  7.000 | max= 16.000
# episode= 309 | treward=  7.000 | max= 16.000
# episode= 310 | treward= 11.000 | max= 16.000
# episode= 311 | treward= 13.000 | max= 16.000
# episode= 312 | treward=  9.000 | max= 16.000
# episode= 313 | treward=  6.000 | max= 16.000
# episode= 314 | treward=  7.000 | max= 16.000
# episode= 315 | treward=  6.000 | max= 16.000
# episode= 316 | treward=  6.000 | max= 16.000
# episode= 317 | treward=  9.000 | max= 16.000
# episode= 318 | treward= 10.000 | max= 16.000
# episode= 319 | treward=  5.000 | max= 16.000
# episode= 320 | treward=  8.000 | max= 16.000
# episode= 321 | treward=  5.000 | max= 16.000
# episode= 322 | treward=  4.000 | max= 16.000
# episode= 323 | treward=  7.000 | max= 16.000
# episode= 324 | treward=  8.000 | max= 16.000
# episode= 325 | treward=  8.000 | max= 16.000
# episode= 326 | treward=  8.000 | max= 16.000
# episode= 327 | treward=  9.000 | max= 16.000
# episode= 328 | treward=  8.000 | max= 16.000
# episode= 329 | treward=  9.000 | max= 16.000
# episode= 330 | treward=  9.000 | max= 16.000
# episode= 331 | treward=  7.000 | max= 16.000
# episode= 332 | treward=  8.000 | max= 16.000
# episode= 333 | treward=  8.000 | max= 16.000
# episode= 334 | treward=  7.000 | max= 16.000
# episode= 335 | treward=  7.000 | max= 16.000
# episode= 336 | treward=  6.000 | max= 16.000
# episode= 337 | treward=  9.000 | max= 16.000
# episode= 338 | treward=  8.000 | max= 16.000
# episode= 339 | treward=  7.000 | max= 16.000
# episode= 340 | treward=  9.000 | max= 16.000
# episode= 341 | treward=  7.000 | max= 16.000
# episode= 342 | treward=  6.000 | max= 16.000
# episode= 343 | treward=  9.000 | max= 16.000
# episode= 344 | treward=  9.000 | max= 16.000
# episode= 345 | treward= 10.000 | max= 16.000
# episode= 346 | treward=  8.000 | max= 16.000
# episode= 347 | treward=  7.000 | max= 16.000
# episode= 348 | treward=  9.000 | max= 16.000
# episode= 349 | treward=  7.000 | max= 16.000
# episode= 350 | treward=  8.000 | max= 16.000
# episode= 351 | treward=  6.000 | max= 16.000
# episode= 352 | treward=  8.000 | max= 16.000
# episode= 353 | treward=  6.000 | max= 16.000
# episode= 354 | treward=  8.000 | max= 16.000
# episode= 355 | treward=  9.000 | max= 16.000
# episode= 356 | treward=  7.000 | max= 16.000
# episode= 357 | treward= 10.000 | max= 16.000
# episode= 358 | treward=  8.000 | max= 16.000
# episode= 359 | treward=  9.000 | max= 16.000
# episode= 360 | treward= 10.000 | max= 16.000
# episode= 361 | treward=  7.000 | max= 16.000
# episode= 362 | treward=  6.000 | max= 16.000
# episode= 363 | treward=  8.000 | max= 16.000
# episode= 364 | treward=  7.000 | max= 16.000
# episode= 365 | treward=  6.000 | max= 16.000
# episode= 366 | treward=  7.000 | max= 16.000
# episode= 367 | treward= 10.000 | max= 16.000
# episode= 368 | treward=  8.000 | max= 16.000
# episode= 369 | treward=  6.000 | max= 16.000
# episode= 370 | treward=  6.000 | max= 16.000
# episode= 371 | treward=  5.000 | max= 16.000
# episode= 372 | treward=  9.000 | max= 16.000
# episode= 373 | treward=  8.000 | max= 16.000
# episode= 374 | treward=  8.000 | max= 16.000
# episode= 375 | treward=  6.000 | max= 16.000
# episode= 376 | treward=  7.000 | max= 16.000
# episode= 377 | treward=  9.000 | max= 16.000
# episode= 378 | treward= 11.000 | max= 16.000
# episode= 379 | treward=  8.000 | max= 16.000
# episode= 380 | treward=  8.000 | max= 16.000
# episode= 381 | treward= 10.000 | max= 16.000
# episode= 382 | treward=  3.000 | max= 16.000
# episode= 383 | treward=  7.000 | max= 16.000
# episode= 384 | treward=  8.000 | max= 16.000
# episode= 385 | treward=  5.000 | max= 16.000
# episode= 386 | treward=  7.000 | max= 16.000
# episode= 387 | treward=  9.000 | max= 16.000
# episode= 388 | treward=  6.000 | max= 16.000
# episode= 389 | treward=  8.000 | max= 16.000
# episode= 390 | treward=  9.000 | max= 16.000
# episode= 391 | treward= 10.000 | max= 16.000
# episode= 392 | treward=  5.000 | max= 16.000
# episode= 393 | treward=  7.000 | max= 16.000
# episode= 394 | treward=  6.000 | max= 16.000
# episode= 395 | treward= 10.000 | max= 16.000
# episode= 396 | treward=  5.000 | max= 16.000
# episode= 397 | treward= 10.000 | max= 16.000
# episode= 398 | treward=  7.000 | max= 16.000
# episode= 399 | treward=  8.000 | max= 16.000
# episode= 400 | treward= 10.000 | max= 16.000
# episode= 401 | treward=  8.000 | max= 16.000
# episode= 402 | treward= 11.000 | max= 16.000
# episode= 403 | treward=  7.000 | max= 16.000
# episode= 404 | treward=  9.000 | max= 16.000
# episode= 405 | treward=  7.000 | max= 16.000
# episode= 406 | treward=  7.000 | max= 16.000
# episode= 407 | treward=  6.000 | max= 16.000
# episode= 408 | treward=  9.000 | max= 16.000
# episode= 409 | treward=  6.000 | max= 16.000
# episode= 410 | treward=  7.000 | max= 16.000
# episode= 411 | treward=  9.000 | max= 16.000
# episode= 412 | treward=  9.000 | max= 16.000
# episode= 413 | treward=  7.000 | max= 16.000
# episode= 414 | treward=  7.000 | max= 16.000
# episode= 415 | treward=  5.000 | max= 16.000
# episode= 416 | treward= 10.000 | max= 16.000
# episode= 417 | treward=  6.000 | max= 16.000
# episode= 418 | treward=  8.000 | max= 16.000
# episode= 419 | treward=  7.000 | max= 16.000
# episode= 420 | treward=  8.000 | max= 16.000
# episode= 421 | treward= 10.000 | max= 16.000
# episode= 422 | treward=  9.000 | max= 16.000
# episode= 423 | treward=  8.000 | max= 16.000
# episode= 424 | treward=  6.000 | max= 16.000
# episode= 425 | treward=  9.000 | max= 16.000
# episode= 426 | treward= 11.000 | max= 16.000
# episode= 427 | treward=  5.000 | max= 16.000
# episode= 428 | treward= 11.000 | max= 16.000
# episode= 429 | treward=  7.000 | max= 16.000
# episode= 430 | treward= 11.000 | max= 16.000
# episode= 431 | treward=  5.000 | max= 16.000
# episode= 432 | treward=  7.000 | max= 16.000
# episode= 433 | treward=  7.000 | max= 16.000
# episode= 434 | treward=  7.000 | max= 16.000
# episode= 435 | treward=  7.000 | max= 16.000
# episode= 436 | treward=  6.000 | max= 16.000
# episode= 437 | treward=  8.000 | max= 16.000
# episode= 438 | treward=  8.000 | max= 16.000
# episode= 439 | treward=  5.000 | max= 16.000
# episode= 440 | treward= 10.000 | max= 16.000
# episode= 441 | treward= 11.000 | max= 16.000
# episode= 442 | treward=  9.000 | max= 16.000
# episode= 443 | treward=  8.000 | max= 16.000
# episode= 444 | treward=  7.000 | max= 16.000
# episode= 445 | treward=  8.000 | max= 16.000
# episode= 446 | treward=  9.000 | max= 16.000
# episode= 447 | treward=  8.000 | max= 16.000
# episode= 448 | treward=  7.000 | max= 16.000
# episode= 449 | treward= 10.000 | max= 16.000
# episode= 450 | treward= 10.000 | max= 16.000
# episode= 451 | treward=  9.000 | max= 16.000
# episode= 452 | treward= 10.000 | max= 16.000
# episode= 453 | treward=  7.000 | max= 16.000
# episode= 454 | treward=  8.000 | max= 16.000
# episode= 455 | treward= 10.000 | max= 16.000
# episode= 456 | treward= 11.000 | max= 16.000
# episode= 457 | treward=  7.000 | max= 16.000
# episode= 458 | treward= 10.000 | max= 16.000
# episode= 459 | treward=  6.000 | max= 16.000
# episode= 460 | treward=  4.000 | max= 16.000
# episode= 461 | treward=  7.000 | max= 16.000
# episode= 462 | treward=  6.000 | max= 16.000
# episode= 463 | treward=  9.000 | max= 16.000
# episode= 464 | treward=  9.000 | max= 16.000
# episode= 465 | treward= 12.000 | max= 16.000
# episode= 466 | treward=  7.000 | max= 16.000
# episode= 467 | treward=  9.000 | max= 16.000
# episode= 468 | treward=  9.000 | max= 16.000
# episode= 469 | treward=  7.000 | max= 16.000
# episode= 470 | treward=  5.000 | max= 16.000
# episode= 471 | treward=  7.000 | max= 16.000
# episode= 472 | treward=  8.000 | max= 16.000
# episode= 473 | treward= 11.000 | max= 16.000
# episode= 474 | treward= 11.000 | max= 16.000
# episode= 475 | treward=  9.000 | max= 16.000
# episode= 476 | treward=  8.000 | max= 16.000
# episode= 477 | treward=  9.000 | max= 16.000
# episode= 478 | treward=  8.000 | max= 16.000
# episode= 479 | treward=  7.000 | max= 16.000
# episode= 480 | treward= 10.000 | max= 16.000
# episode= 481 | treward=  6.000 | max= 16.000
# episode= 482 | treward=  8.000 | max= 16.000
# episode= 483 | treward=  9.000 | max= 16.000
# episode= 484 | treward=  9.000 | max= 16.000
# episode= 485 | treward=  9.000 | max= 16.000
# episode= 486 | treward=  9.000 | max= 16.000
# episode= 487 | treward=  9.000 | max= 16.000
# episode= 488 | treward=  8.000 | max= 16.000
# episode= 489 | treward= 10.000 | max= 16.000
# episode= 490 | treward=  7.000 | max= 16.000
# episode= 491 | treward=  5.000 | max= 16.000
# episode= 492 | treward= 10.000 | max= 16.000
# episode= 493 | treward= 10.000 | max= 16.000
# episode= 494 | treward=  7.000 | max= 16.000
# episode= 495 | treward=  9.000 | max= 16.000
# episode= 496 | treward=  9.000 | max= 16.000
# episode= 497 | treward=  8.000 | max= 16.000
# episode= 498 | treward=  4.000 | max= 16.000
# episode= 499 | treward=  6.000 | max= 16.000
# episode= 500 | treward=  7.000 | max= 16.000
# CPU times: total: 1.7 s
# Wall time: 2.34 s

# %%
dqlagent.test(3)
# Out:
# total reward=2507 | accuracy=0.517
# total reward=2507 | accuracy=0.525
# total reward=2507 | accuracy=0.499

# %%
from simulation import Simulation

# %%
random.seed(500)

# %%
simulation = Simulation('SYMBOL', 'r', 4, '2025-1-1', '2027-1-1',
                2 * 252, min_accuracy=0.5, x0=1, kappa=1,
                theta=0.75, sigma=0.1, new=True, normalize=True)

# %%
for t in range(5):
    simulation.reset()
    #simulation.data[simulation.symbol].plot(title=simulation.symbol, lw=1.0, c='b')

# %%
random.seed(100)
np.random.seed(100)
torch.manual_seed(100)

# %%
agent = DQLAgent(simulation.symbol, simulation.feature,
                 simulation.n_features, simulation)

# %%
# %time agent.learn(250)
# Out:
# episode=   1 | treward= 12.000 | max= 12.000
# episode=   2 | treward=  6.000 | max= 12.000
# episode=   3 | treward= 14.000 | max= 14.000
# episode=   4 | treward=259.000 | max=259.000
# episode=   5 | treward=  5.000 | max=259.000
# episode=   6 | treward=  8.000 | max=259.000
# episode=   7 | treward= 22.000 | max=259.000
# episode=   8 | treward=  5.000 | max=259.000
# episode=   9 | treward= 18.000 | max=259.000
# episode=  10 | treward=  6.000 | max=259.000
# episode=  11 | treward=182.000 | max=259.000
# episode=  12 | treward= 44.000 | max=259.000
# episode=  13 | treward=  6.000 | max=259.000
# episode=  14 | treward=263.000 | max=263.000
# episode=  15 | treward=  4.000 | max=263.000
# episode=  16 | treward=  9.000 | max=263.000
# episode=  17 | treward=  7.000 | max=263.000
# episode=  18 | treward= 32.000 | max=263.000
# episode=  19 | treward= 57.000 | max=263.000
# episode=  20 | treward=  8.000 | max=263.000
# episode=  21 | treward=271.000 | max=271.000
# episode=  22 | treward=  7.000 | max=271.000
# episode=  23 | treward=  7.000 | max=271.000
# episode=  24 | treward=  5.000 | max=271.000
# episode=  25 | treward= 32.000 | max=271.000
# episode=  26 | treward=  8.000 | max=271.000
# episode=  27 | treward=  6.000 | max=271.000
# episode=  28 | treward=  5.000 | max=271.000
# episode=  29 | treward=  7.000 | max=271.000
# episode=  30 | treward= 31.000 | max=271.000
# episode=  31 | treward= 16.000 | max=271.000
# episode=  32 | treward=  9.000 | max=271.000
# episode=  33 | treward=  7.000 | max=271.000
# episode=  34 | treward=  6.000 | max=271.000
# episode=  35 | treward= 10.000 | max=271.000
# episode=  36 | treward=  7.000 | max=271.000
# episode=  37 | treward= 17.000 | max=271.000
# episode=  38 | treward=265.000 | max=271.000
# episode=  39 | treward= 14.000 | max=271.000
# episode=  40 | treward=  7.000 | max=271.000
# episode=  41 | treward= 88.000 | max=271.000
# episode=  42 | treward= 20.000 | max=271.000
# episode=  43 | treward=265.000 | max=271.000
# episode=  44 | treward=  6.000 | max=271.000
# episode=  45 | treward= 10.000 | max=271.000
# episode=  46 | treward= 13.000 | max=271.000
# episode=  47 | treward=  5.000 | max=271.000
# episode=  48 | treward=  7.000 | max=271.000
# episode=  49 | treward=  7.000 | max=271.000
# episode=  50 | treward= 47.000 | max=271.000
# episode=  51 | treward=  9.000 | max=271.000
# episode=  52 | treward= 40.000 | max=271.000
# episode=  53 | treward= 20.000 | max=271.000
# episode=  54 | treward=  8.000 | max=271.000
# episode=  55 | treward=170.000 | max=271.000
# episode=  56 | treward= 11.000 | max=271.000
# episode=  57 | treward=  8.000 | max=271.000
# episode=  58 | treward=  7.000 | max=271.000
# episode=  59 | treward=265.000 | max=271.000
# episode=  60 | treward= 12.000 | max=271.000
# episode=  61 | treward=  7.000 | max=271.000
# episode=  62 | treward= 37.000 | max=271.000
# episode=  63 | treward= 20.000 | max=271.000
# episode=  64 | treward= 24.000 | max=271.000
# episode=  65 | treward=  8.000 | max=271.000
# episode=  66 | treward= 15.000 | max=271.000
# episode=  67 | treward= 10.000 | max=271.000
# episode=  68 | treward=269.000 | max=271.000
# episode=  69 | treward=  5.000 | max=271.000
# episode=  70 | treward=  7.000 | max=271.000
# episode=  71 | treward=  7.000 | max=271.000
# episode=  72 | treward= 33.000 | max=271.000
# episode=  73 | treward=  7.000 | max=271.000
# episode=  74 | treward=109.000 | max=271.000
# episode=  75 | treward= 12.000 | max=271.000
# episode=  76 | treward=  9.000 | max=271.000
# episode=  77 | treward=  8.000 | max=271.000
# episode=  78 | treward= 12.000 | max=271.000
# episode=  79 | treward= 28.000 | max=271.000
# episode=  80 | treward=  7.000 | max=271.000
# episode=  81 | treward=  6.000 | max=271.000
# episode=  82 | treward=  6.000 | max=271.000
# episode=  83 | treward=  7.000 | max=271.000
# episode=  84 | treward=  8.000 | max=271.000
# episode=  85 | treward=  9.000 | max=271.000
# episode=  86 | treward= 31.000 | max=271.000
# episode=  87 | treward=  7.000 | max=271.000
# episode=  88 | treward= 13.000 | max=271.000
# episode=  89 | treward= 10.000 | max=271.000
# episode=  90 | treward=  8.000 | max=271.000
# episode=  91 | treward=  7.000 | max=271.000
# episode=  92 | treward=264.000 | max=271.000
# episode=  93 | treward=261.000 | max=271.000
# episode=  94 | treward=  8.000 | max=271.000
# episode=  95 | treward= 94.000 | max=271.000
# episode=  96 | treward=  7.000 | max=271.000
# episode=  97 | treward=136.000 | max=271.000
# episode=  98 | treward=  7.000 | max=271.000
# episode=  99 | treward= 23.000 | max=271.000
# episode= 100 | treward=  7.000 | max=271.000
# episode= 101 | treward=  7.000 | max=271.000
# episode= 102 | treward=264.000 | max=271.000
# episode= 103 | treward= 12.000 | max=271.000
# episode= 104 | treward= 35.000 | max=271.000
# episode= 105 | treward= 78.000 | max=271.000
# episode= 106 | treward= 82.000 | max=271.000
# episode= 107 | treward=  8.000 | max=271.000
# episode= 108 | treward=  9.000 | max=271.000
# episode= 109 | treward=  7.000 | max=271.000
# episode= 110 | treward=  4.000 | max=271.000
# episode= 111 | treward=  7.000 | max=271.000
# episode= 112 | treward=  6.000 | max=271.000
# episode= 113 | treward=268.000 | max=271.000
# episode= 114 | treward= 49.000 | max=271.000
# episode= 115 | treward=  6.000 | max=271.000
# episode= 116 | treward=  7.000 | max=271.000
# episode= 117 | treward=  5.000 | max=271.000
# episode= 118 | treward= 15.000 | max=271.000
# episode= 119 | treward=  9.000 | max=271.000
# episode= 120 | treward=260.000 | max=271.000
# episode= 121 | treward= 23.000 | max=271.000
# episode= 122 | treward= 11.000 | max=271.000
# episode= 123 | treward=  7.000 | max=271.000
# episode= 124 | treward= 13.000 | max=271.000
# episode= 125 | treward=  5.000 | max=271.000
# episode= 126 | treward=  4.000 | max=271.000
# episode= 127 | treward=  7.000 | max=271.000
# episode= 128 | treward=259.000 | max=271.000
# episode= 129 | treward=  6.000 | max=271.000
# episode= 130 | treward=  7.000 | max=271.000
# episode= 131 | treward=  7.000 | max=271.000
# episode= 132 | treward=  6.000 | max=271.000
# episode= 133 | treward=  6.000 | max=271.000
# episode= 134 | treward=  4.000 | max=271.000
# episode= 135 | treward= 10.000 | max=271.000
# episode= 136 | treward= 32.000 | max=271.000
# episode= 137 | treward=  9.000 | max=271.000
# episode= 138 | treward=  8.000 | max=271.000
# episode= 139 | treward=  8.000 | max=271.000
# episode= 140 | treward= 18.000 | max=271.000
# episode= 141 | treward=  6.000 | max=271.000
# episode= 142 | treward=  6.000 | max=271.000
# episode= 143 | treward=266.000 | max=271.000
# episode= 144 | treward=  6.000 | max=271.000
# episode= 145 | treward=  9.000 | max=271.000
# episode= 146 | treward=  5.000 | max=271.000
# episode= 147 | treward=140.000 | max=271.000
# episode= 148 | treward= 10.000 | max=271.000
# episode= 149 | treward= 70.000 | max=271.000
# episode= 150 | treward=100.000 | max=271.000
# episode= 151 | treward=  8.000 | max=271.000
# episode= 152 | treward=  8.000 | max=271.000
# episode= 153 | treward=  5.000 | max=271.000
# episode= 154 | treward=  6.000 | max=271.000
# episode= 155 | treward= 25.000 | max=271.000
# episode= 156 | treward=  6.000 | max=271.000
# episode= 157 | treward=  9.000 | max=271.000
# episode= 158 | treward= 14.000 | max=271.000
# episode= 159 | treward=  7.000 | max=271.000
# episode= 160 | treward= 13.000 | max=271.000
# episode= 161 | treward=277.000 | max=277.000
# episode= 162 | treward= 56.000 | max=277.000
# episode= 163 | treward=  9.000 | max=277.000
# episode= 164 | treward= 17.000 | max=277.000
# episode= 165 | treward=  7.000 | max=277.000
# episode= 166 | treward=  5.000 | max=277.000
# episode= 167 | treward=  5.000 | max=277.000
# episode= 168 | treward=  9.000 | max=277.000
# episode= 169 | treward= 12.000 | max=277.000
# episode= 170 | treward=254.000 | max=277.000
# episode= 171 | treward=  8.000 | max=277.000
# episode= 172 | treward=  7.000 | max=277.000
# episode= 173 | treward=  4.000 | max=277.000
# episode= 174 | treward= 18.000 | max=277.000
# episode= 175 | treward= 16.000 | max=277.000
# episode= 176 | treward=281.000 | max=281.000
# episode= 177 | treward= 12.000 | max=281.000
# episode= 178 | treward=  8.000 | max=281.000
# episode= 179 | treward=  8.000 | max=281.000
# episode= 180 | treward=  9.000 | max=281.000
# episode= 181 | treward=  5.000 | max=281.000
# episode= 182 | treward=  7.000 | max=281.000
# episode= 183 | treward=284.000 | max=284.000
# episode= 184 | treward=273.000 | max=284.000
# episode= 185 | treward= 45.000 | max=284.000
# episode= 186 | treward= 33.000 | max=284.000
# episode= 187 | treward=131.000 | max=284.000
# episode= 188 | treward=  6.000 | max=284.000
# episode= 189 | treward=  6.000 | max=284.000
# episode= 190 | treward=  7.000 | max=284.000
# episode= 191 | treward=  9.000 | max=284.000
# episode= 192 | treward= 15.000 | max=284.000
# episode= 193 | treward=206.000 | max=284.000
# episode= 194 | treward=263.000 | max=284.000
# episode= 195 | treward=  6.000 | max=284.000
# episode= 196 | treward=  7.000 | max=284.000
# episode= 197 | treward=  6.000 | max=284.000
# episode= 198 | treward= 10.000 | max=284.000
# episode= 199 | treward=180.000 | max=284.000
# episode= 200 | treward=  9.000 | max=284.000
# episode= 201 | treward=  6.000 | max=284.000
# episode= 202 | treward=191.000 | max=284.000
# episode= 203 | treward=256.000 | max=284.000
# episode= 204 | treward=  7.000 | max=284.000
# episode= 205 | treward=  5.000 | max=284.000
# episode= 206 | treward=269.000 | max=284.000
# episode= 207 | treward=  9.000 | max=284.000
# episode= 208 | treward= 49.000 | max=284.000
# episode= 209 | treward=265.000 | max=284.000
# episode= 210 | treward= 20.000 | max=284.000
# episode= 211 | treward=270.000 | max=284.000
# episode= 212 | treward= 40.000 | max=284.000
# episode= 213 | treward=  6.000 | max=284.000
# episode= 214 | treward= 11.000 | max=284.000
# episode= 215 | treward=267.000 | max=284.000
# episode= 216 | treward=  6.000 | max=284.000
# episode= 217 | treward=  6.000 | max=284.000
# episode= 218 | treward= 10.000 | max=284.000
# episode= 219 | treward=178.000 | max=284.000
# episode= 220 | treward=259.000 | max=284.000
# episode= 221 | treward=  6.000 | max=284.000
# episode= 222 | treward=  4.000 | max=284.000
# episode= 223 | treward=146.000 | max=284.000
# episode= 224 | treward= 10.000 | max=284.000
# episode= 225 | treward=  5.000 | max=284.000
# episode= 226 | treward=259.000 | max=284.000
# episode= 227 | treward=  8.000 | max=284.000
# episode= 228 | treward=  4.000 | max=284.000
# episode= 229 | treward=  7.000 | max=284.000
# episode= 230 | treward=257.000 | max=284.000
# episode= 231 | treward=  9.000 | max=284.000
# episode= 232 | treward= 50.000 | max=284.000
# episode= 233 | treward=195.000 | max=284.000
# episode= 234 | treward= 29.000 | max=284.000
# episode= 235 | treward=  8.000 | max=284.000
# episode= 236 | treward= 97.000 | max=284.000
# episode= 237 | treward= 10.000 | max=284.000
# episode= 238 | treward=153.000 | max=284.000
# episode= 239 | treward=  4.000 | max=284.000
# episode= 240 | treward= 32.000 | max=284.000
# episode= 241 | treward= 37.000 | max=284.000
# episode= 242 | treward=  7.000 | max=284.000
# episode= 243 | treward=  7.000 | max=284.000
# episode= 244 | treward=266.000 | max=284.000
# episode= 245 | treward=255.000 | max=284.000
# episode= 246 | treward= 13.000 | max=284.000
# episode= 247 | treward= 17.000 | max=284.000
# episode= 248 | treward= 18.000 | max=284.000
# episode= 249 | treward=270.000 | max=284.000
# episode= 250 | treward=  8.000 | max=284.000
# CPU times: total: 5 s
# Wall time: 6.53 s

# %%
agent.test(5)
# Out:
# total reward= 499 | accuracy=0.499
# total reward= 499 | accuracy=0.505
# total reward= 499 | accuracy=0.483
# total reward= 499 | accuracy=0.499
# total reward= 499 | accuracy=0.517

# %%
class ActionSpace:
    n = 2
    def sample(self):
        return random.randint(0, 1)

# %%
class Trading:
    def __init__(self, symbol, features, window, lags,
                 start, end, periods,
                 x0=100, kappa=1, theta=100, sigma=0.2,
                 leverage=1, min_accuracy=0.5, min_performance=0.85,
                 mu=None, std=None,
                 new=True, normalize=True):
        self.symbol = symbol
        self.features = features
        self.n_features = len(features)
        self.window = window
        self.lags = lags
        self.start = start
        self.end = end
        self.periods = periods
        self.x0 = x0
        self.kappa = kappa
        self.theta = theta
        self.sigma = sigma
        self.leverage = leverage
        self.min_accuracy = min_accuracy
        self.min_performance = min_performance
        self.start = start
        self.end = end
        self.mu = mu
        self.std = std
        self.new = new
        self.normalize = normalize
        self.action_space = ActionSpace()
        self._simulate_data()
        self._prepare_data()

# %%
class Trading(Trading):
    def _simulate_data(self):
        index = pd.date_range(start=self.start,
                    end=self.end, periods=self.periods)
        s = [self.x0]
        dt = (index[-1] - index[0]).days / 365 / self.periods
        for t in range(1, len(index)):
            s_ = (s[t - 1] + self.kappa * (self.theta - s[t - 1]) * dt +
              s[t - 1] * self.sigma * math.sqrt(dt) *
                random.gauss(0, 1))
            s.append(s_)
        self.data = pd.DataFrame(s, columns=[self.symbol], index=index)

# %%
class Trading(Trading):
    def _prepare_data(self):
        self.data['r'] = np.log(self.data / self.data.shift(1))
        self.data.dropna(inplace=True)
        # additional features
        if self.window > 0:
            self.data['SMA'] = self.data[
                self.symbol].rolling(self.window).mean()
            self.data['DEL'] = self.data[
                self.symbol] - self.data['SMA']
            self.data['MIN'] = self.data[
                self.symbol].rolling(self.window).min()
            self.data['MAX'] = self.data[
                self.symbol].rolling(self.window).max()
            self.data['MOM'] = self.data['r'].rolling(
                self.window).mean()
            # add more features here
            self.data.dropna(inplace=True)
        if self.normalize:
            if self.mu is None or self.std is None:
                self.mu = self.data.mean()
                self.std = self.data.std()
            self.data_ = (self.data - self.mu) / self.std
        else:
            self.data_ = self.data.copy()
        self.data['d'] = np.where(self.data['r'] > 0, 1, 0)
        self.data['d'] = self.data['d'].astype(int)

# %%
class Trading(Trading):
    def _get_state(self):
        return self.data_[self.features].iloc[self.bar -
                                self.lags:self.bar]
    def seed(self, seed):
        random.seed(seed)
        np.random.seed(seed)
        torch.manual_seed(seed)
    def reset(self):
        if self.new:
            self._simulate_data()
            self._prepare_data()
        self.treward = 0
        self.accuracy = 0
        self.actions = list()
        self.returns = list()
        self.performance = 1
        self.bar = self.lags
        state = self._get_state()
        return state.values, {}

# %%
class Trading(Trading):
    def step(self, action):
        correct = action == self.data['d'].iloc[self.bar]
        ret = self.data['r'].iloc[self.bar] * self.leverage
        reward_ = 1 if correct else 0
        pl = abs(ret) if correct else -abs(ret)
        reward = reward_
        # alternative options:
        # reward = pl  # only the P&L in log returns
        # reward = reward_ + 10 * pl  # the reward + the scaled P&L
        self.treward += reward
        self.bar += 1
        self.accuracy = self.treward / (self.bar - self.lags) 
        self.performance *= math.exp(pl)
        if self.bar >= len(self.data):
            done = True
        elif reward_ == 1:
            done = False
        elif (self.accuracy < self.min_accuracy and
              self.bar > self.lags + 15):
            done = True
        elif (self.performance < self.min_performance and
              self.bar > self.lags + 15):
            done = True
        else:
            done = False
        state = self._get_state()
        return state.values, reward, done, False, {}

# %%
symbol = 'SYMBOL'

# %%
trading = Trading(symbol, [symbol, 'r', 'DEL'], window=10, lags=5,
            start='2024-1-1', end='2026-1-1', periods=504,
            x0=100, kappa=2, theta=300, sigma=0.1, normalize=False)

# %%
random.seed(750)

# %%
trading.reset()
# Out:
# (array([[115.90591443,   0.01926915,   6.89239862],
#         [117.17850569,   0.01091968,   6.5901155 ],
#         [118.79489427,   0.01369997,   6.65876779],
#         [120.63380354,   0.01536111,   6.92684742],
#         [121.81132396,   0.00971378,   6.65768164]]),
#  {})

# %%
trading.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 494 entries, 2024-01-15 12:47:14.194831014 to 2026-01-01 00:00:00
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SYMBOL  494 non-null    float64
#  1   r       494 non-null    float64
#  2   SMA     494 non-null    float64
#  3   DEL     494 non-null    float64
#  4   MIN     494 non-null    float64
#  5   MAX     494 non-null    float64
#  6   MOM     494 non-null    float64
#  7   d       494 non-null    int32
# dtypes: float64(7), int32(1)
# memory usage: 32.8 KB

# %%
#trading.data.iloc[-200:][[trading.symbol, 'SMA', 'MIN', 'MAX']].plot(style=['b-', 'r--', 'g:', 'g:'], lw=1.0);

# %%
random.seed(100)
np.random.seed(100)
torch.manual_seed(100)

# %%
trading = Trading(symbol, ['r', 'DEL', 'MOM'], window=10, lags=8,
            start='2024-1-1', end='2026-1-1', periods=2 * 252,
            x0=100, kappa=2, theta=50, sigma=0.1,
            leverage=1, min_accuracy=0.5, min_performance=0.85,
            new=True, normalize=True)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.python.keras.layers import Dense, Flatten
from keras import Sequential
import os
import random
import warnings
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque

warnings.simplefilter('ignore')
os.environ['PYTHONHASHSEED'] = '0'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim, hu=24):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(state_dim, hu)
        self.fc2 = nn.Linear(hu, hu)
        self.fc3 = nn.Linear(hu, action_dim)
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class DQLAgent:
    def __init__(self, symbol, feature, n_features, env, hu=24, lr=0.001):
        self.epsilon = 1.0
        self.epsilon_decay = 0.9975
        self.epsilon_min = 0.1
        self.memory = deque(maxlen=2000)
        self.batch_size = 32
        self.gamma = 0.5
        self.trewards = []
        self.max_treward = -np.inf
        self.n_features = n_features
        self.env = env
        self.episodes = 0
        # Q-Network and optimizer
        self.model = QNetwork(self.n_features, self.env.action_space.n, hu).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.MSELoss()
        self.symbol = symbol
        self.feature = feature
        self.n_features = n_features

        # Si env est un entier, nous devons l'adapter
        if isinstance(env, int):
            # Créer une structure simple pour simuler l'environnement
            class SimpleEnv:
                def __init__(self, n_actions):
                    self.action_space = type('obj', (object,), {'n': n_actions})

            self.env = SimpleEnv(env)  # env représente le nombre d'actions
        else:
            self.env = env  # env est déjà un environnement approprié

        self.hu = hu
        self.lr = lr

        # Reste du code d'initialisation...
        self.episodes = 0
        # Q-Network and optimizer
        self.model = QNetwork(self.n_features, self.env.action_space.n, hu).to(device)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.MSELoss()



    def _reshape(self, state):
        state = state.flatten()
        return np.reshape(state, [1, len(state)])

    def act(self, state):
        if random.random() < self.epsilon:
            return self.env.action_space.sample()
        state_tensor = torch.FloatTensor(state).to(device)
        if state_tensor.dim() == 1:
            state_tensor = state_tensor.unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state_tensor)
        return int(torch.argmax(q_values[0]).item())

    def replay(self):
        if len(self.memory) < self.batch_size:
            return
        batch = random.sample(self.memory, self.batch_size)
        states = np.vstack([e[0] for e in batch])
        actions = np.array([e[1] for e in batch])
        next_states = np.vstack([e[2] for e in batch])
        rewards = np.array([e[3] for e in batch], dtype=np.float32)
        dones = np.array([e[4] for e in batch], dtype=bool)

        states_tensor = torch.FloatTensor(states).to(device)
        next_states_tensor = torch.FloatTensor(next_states).to(device)
        actions_tensor = torch.LongTensor(actions).unsqueeze(1).to(device)
        rewards_tensor = torch.FloatTensor(rewards).to(device)
        dones_tensor = torch.BoolTensor(dones).to(device)

        current_q = self.model(states_tensor).gather(1, actions_tensor).squeeze(1)
        next_q = self.model(next_states_tensor).max(1)[0]
        target_q = rewards_tensor + self.gamma * next_q * (~dones_tensor).float()

        loss = self.criterion(current_q, target_q.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def learn(self, episodes):
        for e in range(1, episodes + 1):
            self.episodes += 1
            state, _ = self.env.reset()
            state = self._reshape(state)
            treward = 0
            for f in range(1, 5000):
                self.f = f
                action = self.act(state)
                next_state, reward, done, trunc, _ = self.env.step(action)
                treward += reward
                next_state = self._reshape(next_state)
                self.memory.append((state, action, next_state, reward, done))
                state = next_state
                if done:
                    self.trewards.append(treward)
                    self.max_treward = max(self.max_treward, treward)
                    templ = f'episode={self.episodes:4d} | '
                    templ += f'treward={treward:7.3f} | max={self.max_treward:7.3f}'
                    print(templ, end='\r')
                    break
            if len(self.memory) > self.batch_size:
                self.replay()
            print()

    def test(self, episodes, min_accuracy=0.0, min_performance=0.0, verbose=True, full=True):
        # Backup and set environment thresholds
        ma = getattr(self.env, 'min_accuracy', None)
        if hasattr(self.env, 'min_accuracy'):
            self.env.min_accuracy = min_accuracy
        mp = None
        if hasattr(self.env, 'min_performance'):
            mp = self.env.min_performance
            self.env.min_performance = min_performance
            self.performances = []
        for e in range(1, episodes + 1):
            state, _ = self.env.reset()
            state = self._reshape(state)
            for f in range(1, 5001):
                action = self.act(state)
                state, reward, done, trunc, _ = self.env.step(action)
                state = self._reshape(state)
                if done:
                    templ = f'total reward={f:4d} | accuracy={self.env.accuracy:.3f}'
                    if hasattr(self.env, 'min_performance'):
                        self.performances.append(self.env.performance)
                        templ += f' | performance={self.env.performance:.3f}'
                    if verbose:
                        if full:
                            print(templ)
                        else:
                            print(templ, end='\r')
                    break
        # Restore environment thresholds
        if hasattr(self.env, 'min_accuracy') and ma is not None:
            self.env.min_accuracy = ma
        if mp is not None:
            self.env.min_performance = mp
        print()



class TradingAgent(DQLAgent):
    def _create_model(self, hu, lr):
        self.model = Sequential()
        self.model.add(Dense(hu, input_dim=
            self.env.lags * self.env.n_features,
                        activation='relu'))
        self.model.add(Flatten())
        self.model.add(Dense(hu, activation='relu'))
        self.model.add(Dense(2, activation='linear'))
        self.model.compile(loss='mse',
            optimizer=Adam(learning_rate=lr))

tradingagent = TradingAgent(trading.symbol, trading.features,
                 trading.lags * trading.n_features, trading, hu=24, lr=0.0001)

# %%
# %%time
tradingagent.test(100, min_accuracy=0.0, min_performance=0.0, verbose=True, full=False)
# Out:
# total reward= 486 | accuracy=0.481 | performance=0.952
# CPU times: total: 32.3 s
# Wall time: 56.5 s

# %%
random_performances = tradingagent.performances

# %%
sum(random_performances) / len(random_performances)
# Out:
# 0.993043981488391

# %%
#plt.hist(random_performances, bins=50, color='b')
#plt.xlabel('gross performance')
#plt.ylabel('frequency');

# %%
# %time tradingagent.learn(500)
# Out:
# episode=   1 | treward= 11.000 | max= 11.000
# episode=   2 | treward=121.000 | max=121.000
# episode=   3 | treward=  6.000 | max=121.000
# episode=   4 | treward=  9.000 | max=121.000
# episode=   5 | treward=  7.000 | max=121.000
# episode=   6 | treward=  5.000 | max=121.000
# episode=   7 | treward=  4.000 | max=121.000
# episode=   8 | treward= 11.000 | max=121.000
# episode=   9 | treward= 29.000 | max=121.000
# episode=  10 | treward=  8.000 | max=121.000
# episode=  11 | treward= 17.000 | max=121.000
# episode=  12 | treward= 11.000 | max=121.000
# episode=  13 | treward= 31.000 | max=121.000
# episode=  14 | treward=  8.000 | max=121.000
# episode=  15 | treward= 11.000 | max=121.000
# episode=  16 | treward= 14.000 | max=121.000
# episode=  17 | treward=  7.000 | max=121.000
# episode=  18 | treward=  7.000 | max=121.000
# episode=  19 | treward=256.000 | max=256.000
# episode=  20 | treward=  5.000 | max=256.000
# episode=  21 | treward= 13.000 | max=256.000
# episode=  22 | treward= 18.000 | max=256.000
# episode=  23 | treward=  5.000 | max=256.000
# episode=  24 | treward=115.000 | max=256.000
# episode=  25 | treward=  8.000 | max=256.000
# episode=  26 | treward=  8.000 | max=256.000
# episode=  27 | treward=162.000 | max=256.000
# episode=  28 | treward= 11.000 | max=256.000
# episode=  29 | treward=  9.000 | max=256.000
# episode=  30 | treward= 16.000 | max=256.000
# episode=  31 | treward= 11.000 | max=256.000
# episode=  32 | treward= 14.000 | max=256.000
# episode=  33 | treward=  9.000 | max=256.000
# episode=  34 | treward=  6.000 | max=256.000
# episode=  35 | treward= 38.000 | max=256.000
# episode=  36 | treward=133.000 | max=256.000
# episode=  37 | treward= 11.000 | max=256.000
# episode=  38 | treward=264.000 | max=264.000
# episode=  39 | treward=  8.000 | max=264.000
# episode=  40 | treward=  7.000 | max=264.000
# episode=  41 | treward=  7.000 | max=264.000
# episode=  42 | treward=249.000 | max=264.000
# episode=  43 | treward= 10.000 | max=264.000
# episode=  44 | treward= 22.000 | max=264.000
# episode=  45 | treward=  7.000 | max=264.000
# episode=  46 | treward=  5.000 | max=264.000
# episode=  47 | treward=  6.000 | max=264.000
# episode=  48 | treward= 51.000 | max=264.000
# episode=  49 | treward= 21.000 | max=264.000
# episode=  50 | treward= 42.000 | max=264.000
# episode=  51 | treward=  8.000 | max=264.000
# episode=  52 | treward= 17.000 | max=264.000
# episode=  53 | treward= 13.000 | max=264.000
# episode=  54 | treward= 52.000 | max=264.000
# episode=  55 | treward= 35.000 | max=264.000
# episode=  56 | treward=  7.000 | max=264.000
# episode=  57 | treward= 31.000 | max=264.000
# episode=  58 | treward=  8.000 | max=264.000
# episode=  59 | treward=  7.000 | max=264.000
# episode=  60 | treward=  3.000 | max=264.000
# episode=  61 | treward= 54.000 | max=264.000
# episode=  62 | treward= 11.000 | max=264.000
# episode=  63 | treward=  6.000 | max=264.000
# episode=  64 | treward= 51.000 | max=264.000
# episode=  65 | treward=  7.000 | max=264.000
# episode=  66 | treward=  5.000 | max=264.000
# episode=  67 | treward=  7.000 | max=264.000
# episode=  68 | treward= 54.000 | max=264.000
# episode=  69 | treward= 47.000 | max=264.000
# episode=  70 | treward=167.000 | max=264.000
# episode=  71 | treward=235.000 | max=264.000
# episode=  72 | treward=  9.000 | max=264.000
# episode=  73 | treward= 16.000 | max=264.000
# episode=  74 | treward= 11.000 | max=264.000
# episode=  75 | treward= 46.000 | max=264.000
# episode=  76 | treward= 69.000 | max=264.000
# episode=  77 | treward=  7.000 | max=264.000
# episode=  78 | treward=  5.000 | max=264.000
# episode=  79 | treward= 16.000 | max=264.000
# episode=  80 | treward=  8.000 | max=264.000
# episode=  81 | treward=  7.000 | max=264.000
# episode=  82 | treward= 13.000 | max=264.000
# episode=  83 | treward=  6.000 | max=264.000
# episode=  84 | treward=  7.000 | max=264.000
# episode=  85 | treward=  7.000 | max=264.000
# episode=  86 | treward=140.000 | max=264.000
# episode=  87 | treward= 17.000 | max=264.000
# episode=  88 | treward=  9.000 | max=264.000
# episode=  89 | treward= 30.000 | max=264.000
# episode=  90 | treward= 52.000 | max=264.000
# episode=  91 | treward= 44.000 | max=264.000
# episode=  92 | treward= 10.000 | max=264.000
# episode=  93 | treward=  7.000 | max=264.000
# episode=  94 | treward=  5.000 | max=264.000
# episode=  95 | treward= 12.000 | max=264.000
# episode=  96 | treward=  7.000 | max=264.000
# episode=  97 | treward=  7.000 | max=264.000
# episode=  98 | treward=  8.000 | max=264.000
# episode=  99 | treward=  7.000 | max=264.000
# episode= 100 | treward= 81.000 | max=264.000
# episode= 101 | treward= 11.000 | max=264.000
# episode= 102 | treward=  6.000 | max=264.000
# episode= 103 | treward=  9.000 | max=264.000
# episode= 104 | treward= 26.000 | max=264.000
# episode= 105 | treward= 28.000 | max=264.000
# episode= 106 | treward=  7.000 | max=264.000
# episode= 107 | treward=  6.000 | max=264.000
# episode= 108 | treward=  7.000 | max=264.000
# episode= 109 | treward=254.000 | max=264.000
# episode= 110 | treward=183.000 | max=264.000
# episode= 111 | treward=257.000 | max=264.000
# episode= 112 | treward= 23.000 | max=264.000
# episode= 113 | treward=  8.000 | max=264.000
# episode= 114 | treward=  7.000 | max=264.000
# episode= 115 | treward= 31.000 | max=264.000
# episode= 116 | treward= 27.000 | max=264.000
# episode= 117 | treward=257.000 | max=264.000
# episode= 118 | treward=252.000 | max=264.000
# episode= 119 | treward=262.000 | max=264.000
# episode= 120 | treward=227.000 | max=264.000
# episode= 121 | treward=  3.000 | max=264.000
# episode= 122 | treward=246.000 | max=264.000
# episode= 123 | treward=168.000 | max=264.000
# episode= 124 | treward= 29.000 | max=264.000
# episode= 125 | treward=  7.000 | max=264.000
# episode= 126 | treward= 12.000 | max=264.000
# episode= 127 | treward= 15.000 | max=264.000
# episode= 128 | treward=  7.000 | max=264.000
# episode= 129 | treward=  8.000 | max=264.000
# episode= 130 | treward= 37.000 | max=264.000
# episode= 131 | treward= 19.000 | max=264.000
# episode= 132 | treward=249.000 | max=264.000
# episode= 133 | treward=  8.000 | max=264.000
# episode= 134 | treward=252.000 | max=264.000
# episode= 135 | treward=  7.000 | max=264.000
# episode= 136 | treward=149.000 | max=264.000
# episode= 137 | treward=  8.000 | max=264.000
# episode= 138 | treward=257.000 | max=264.000
# episode= 139 | treward= 47.000 | max=264.000
# episode= 140 | treward=251.000 | max=264.000
# episode= 141 | treward= 14.000 | max=264.000
# episode= 142 | treward=  7.000 | max=264.000
# episode= 143 | treward=  6.000 | max=264.000
# episode= 144 | treward= 19.000 | max=264.000
# episode= 145 | treward=  7.000 | max=264.000
# episode= 146 | treward= 57.000 | max=264.000
# episode= 147 | treward=  9.000 | max=264.000
# episode= 148 | treward=209.000 | max=264.000
# episode= 149 | treward= 11.000 | max=264.000
# episode= 150 | treward= 63.000 | max=264.000
# episode= 151 | treward=  6.000 | max=264.000
# episode= 152 | treward=112.000 | max=264.000
# episode= 153 | treward=258.000 | max=264.000
# episode= 154 | treward=252.000 | max=264.000
# episode= 155 | treward=111.000 | max=264.000
# episode= 156 | treward=  9.000 | max=264.000
# episode= 157 | treward=  8.000 | max=264.000
# episode= 158 | treward=236.000 | max=264.000
# episode= 159 | treward= 20.000 | max=264.000
# episode= 160 | treward=  8.000 | max=264.000
# episode= 161 | treward=  8.000 | max=264.000
# episode= 162 | treward=263.000 | max=264.000
# episode= 163 | treward=  8.000 | max=264.000
# episode= 164 | treward=  5.000 | max=264.000
# episode= 165 | treward=247.000 | max=264.000
# episode= 166 | treward=258.000 | max=264.000
# episode= 167 | treward= 19.000 | max=264.000
# episode= 168 | treward=  7.000 | max=264.000
# episode= 169 | treward= 22.000 | max=264.000
# episode= 170 | treward=  4.000 | max=264.000
# episode= 171 | treward=255.000 | max=264.000
# episode= 172 | treward=  9.000 | max=264.000
# episode= 173 | treward=  5.000 | max=264.000
# episode= 174 | treward=  9.000 | max=264.000
# episode= 175 | treward= 23.000 | max=264.000
# episode= 176 | treward=256.000 | max=264.000
# episode= 177 | treward= 66.000 | max=264.000
# episode= 178 | treward= 10.000 | max=264.000
# episode= 179 | treward= 45.000 | max=264.000
# episode= 180 | treward=  4.000 | max=264.000
# episode= 181 | treward= 56.000 | max=264.000
# episode= 182 | treward= 98.000 | max=264.000
# episode= 183 | treward= 67.000 | max=264.000
# episode= 184 | treward=  9.000 | max=264.000
# episode= 185 | treward=  9.000 | max=264.000
# episode= 186 | treward= 40.000 | max=264.000
# episode= 187 | treward=259.000 | max=264.000
# episode= 188 | treward=257.000 | max=264.000
# episode= 189 | treward=251.000 | max=264.000
# episode= 190 | treward=259.000 | max=264.000
# episode= 191 | treward=107.000 | max=264.000
# episode= 192 | treward=247.000 | max=264.000
# episode= 193 | treward=254.000 | max=264.000
# episode= 194 | treward=  7.000 | max=264.000
# episode= 195 | treward=  9.000 | max=264.000
# episode= 196 | treward=  7.000 | max=264.000
# episode= 197 | treward= 11.000 | max=264.000
# episode= 198 | treward=  6.000 | max=264.000
# episode= 199 | treward=269.000 | max=269.000
# episode= 200 | treward=  8.000 | max=269.000
# episode= 201 | treward= 11.000 | max=269.000
# episode= 202 | treward=  5.000 | max=269.000
# episode= 203 | treward=  7.000 | max=269.000
# episode= 204 | treward=  8.000 | max=269.000
# episode= 205 | treward=127.000 | max=269.000
# episode= 206 | treward=  6.000 | max=269.000
# episode= 207 | treward=  7.000 | max=269.000
# episode= 208 | treward=261.000 | max=269.000
# episode= 209 | treward=  9.000 | max=269.000
# episode= 210 | treward=252.000 | max=269.000
# episode= 211 | treward=164.000 | max=269.000
# episode= 212 | treward=128.000 | max=269.000
# episode= 213 | treward=116.000 | max=269.000
# episode= 214 | treward=207.000 | max=269.000
# episode= 215 | treward=250.000 | max=269.000
# episode= 216 | treward=  6.000 | max=269.000
# episode= 217 | treward=  7.000 | max=269.000
# episode= 218 | treward=  5.000 | max=269.000
# episode= 219 | treward=264.000 | max=269.000
# episode= 220 | treward= 93.000 | max=269.000
# episode= 221 | treward=  8.000 | max=269.000
# episode= 222 | treward=  7.000 | max=269.000
# episode= 223 | treward=  7.000 | max=269.000
# episode= 224 | treward= 51.000 | max=269.000
# episode= 225 | treward=  6.000 | max=269.000
# episode= 226 | treward=  7.000 | max=269.000
# episode= 227 | treward=  7.000 | max=269.000
# episode= 228 | treward=  7.000 | max=269.000
# episode= 229 | treward= 14.000 | max=269.000
# episode= 230 | treward= 69.000 | max=269.000
# episode= 231 | treward= 68.000 | max=269.000
# episode= 232 | treward=  6.000 | max=269.000
# episode= 233 | treward=  3.000 | max=269.000
# episode= 234 | treward=247.000 | max=269.000
# episode= 235 | treward=245.000 | max=269.000
# episode= 236 | treward=  7.000 | max=269.000
# episode= 237 | treward=  4.000 | max=269.000
# episode= 238 | treward=250.000 | max=269.000
# episode= 239 | treward=  6.000 | max=269.000
# episode= 240 | treward=  7.000 | max=269.000
# episode= 241 | treward=252.000 | max=269.000
# episode= 242 | treward=254.000 | max=269.000
# episode= 243 | treward=256.000 | max=269.000
# episode= 244 | treward= 66.000 | max=269.000
# episode= 245 | treward=  8.000 | max=269.000
# episode= 246 | treward=246.000 | max=269.000
# episode= 247 | treward= 95.000 | max=269.000
# episode= 248 | treward=  5.000 | max=269.000
# episode= 249 | treward=263.000 | max=269.000
# episode= 250 | treward=107.000 | max=269.000
# episode= 251 | treward=254.000 | max=269.000
# episode= 252 | treward= 92.000 | max=269.000
# episode= 253 | treward=252.000 | max=269.000
# episode= 254 | treward= 50.000 | max=269.000
# episode= 255 | treward=250.000 | max=269.000
# episode= 256 | treward= 32.000 | max=269.000
# episode= 257 | treward=268.000 | max=269.000
# episode= 258 | treward=257.000 | max=269.000
# episode= 259 | treward=252.000 | max=269.000
# episode= 260 | treward=  8.000 | max=269.000
# episode= 261 | treward= 18.000 | max=269.000
# episode= 262 | treward= 12.000 | max=269.000
# episode= 263 | treward= 17.000 | max=269.000
# episode= 264 | treward=  9.000 | max=269.000
# episode= 265 | treward=  9.000 | max=269.000
# episode= 266 | treward=248.000 | max=269.000
# episode= 267 | treward= 13.000 | max=269.000
# episode= 268 | treward=256.000 | max=269.000
# episode= 269 | treward= 10.000 | max=269.000
# episode= 270 | treward=251.000 | max=269.000
# episode= 271 | treward= 28.000 | max=269.000
# episode= 272 | treward=  7.000 | max=269.000
# episode= 273 | treward=120.000 | max=269.000
# episode= 274 | treward= 14.000 | max=269.000
# episode= 275 | treward=203.000 | max=269.000
# episode= 276 | treward=264.000 | max=269.000
# episode= 277 | treward=257.000 | max=269.000
# episode= 278 | treward=244.000 | max=269.000
# episode= 279 | treward= 71.000 | max=269.000
# episode= 280 | treward=253.000 | max=269.000
# episode= 281 | treward=205.000 | max=269.000
# episode= 282 | treward=  8.000 | max=269.000
# episode= 283 | treward=  6.000 | max=269.000
# episode= 284 | treward= 65.000 | max=269.000
# episode= 285 | treward= 22.000 | max=269.000
# episode= 286 | treward=  7.000 | max=269.000
# episode= 287 | treward= 65.000 | max=269.000
# episode= 288 | treward=  8.000 | max=269.000
# episode= 289 | treward=  4.000 | max=269.000
# episode= 290 | treward= 42.000 | max=269.000
# episode= 291 | treward= 36.000 | max=269.000
# episode= 292 | treward=  8.000 | max=269.000
# episode= 293 | treward=257.000 | max=269.000
# episode= 294 | treward=  7.000 | max=269.000
# episode= 295 | treward=251.000 | max=269.000
# episode= 296 | treward=  6.000 | max=269.000
# episode= 297 | treward=257.000 | max=269.000
# episode= 298 | treward=265.000 | max=269.000
# episode= 299 | treward=  9.000 | max=269.000
# episode= 300 | treward= 99.000 | max=269.000
# episode= 301 | treward=260.000 | max=269.000
# episode= 302 | treward= 17.000 | max=269.000
# episode= 303 | treward=251.000 | max=269.000
# episode= 304 | treward=259.000 | max=269.000
# episode= 305 | treward= 12.000 | max=269.000
# episode= 306 | treward=223.000 | max=269.000
# episode= 307 | treward= 11.000 | max=269.000
# episode= 308 | treward=254.000 | max=269.000
# episode= 309 | treward=  6.000 | max=269.000
# episode= 310 | treward=  8.000 | max=269.000
# episode= 311 | treward=254.000 | max=269.000
# episode= 312 | treward=256.000 | max=269.000
# episode= 313 | treward=225.000 | max=269.000
# episode= 314 | treward=247.000 | max=269.000
# episode= 315 | treward=  7.000 | max=269.000
# episode= 316 | treward= 14.000 | max=269.000
# episode= 317 | treward=252.000 | max=269.000
# episode= 318 | treward=119.000 | max=269.000
# episode= 319 | treward= 22.000 | max=269.000
# episode= 320 | treward=254.000 | max=269.000
# episode= 321 | treward=268.000 | max=269.000
# episode= 322 | treward= 78.000 | max=269.000
# episode= 323 | treward=  8.000 | max=269.000
# episode= 324 | treward=269.000 | max=269.000
# episode= 325 | treward=242.000 | max=269.000
# episode= 326 | treward=207.000 | max=269.000
# episode= 327 | treward=134.000 | max=269.000
# episode= 328 | treward=174.000 | max=269.000
# episode= 329 | treward= 10.000 | max=269.000
# episode= 330 | treward= 92.000 | max=269.000
# episode= 331 | treward=  6.000 | max=269.000
# episode= 332 | treward=206.000 | max=269.000
# episode= 333 | treward=254.000 | max=269.000
# episode= 334 | treward=  6.000 | max=269.000
# episode= 335 | treward=250.000 | max=269.000
# episode= 336 | treward=264.000 | max=269.000
# episode= 337 | treward=260.000 | max=269.000
# episode= 338 | treward=202.000 | max=269.000
# episode= 339 | treward=156.000 | max=269.000
# episode= 340 | treward=255.000 | max=269.000
# episode= 341 | treward= 10.000 | max=269.000
# episode= 342 | treward= 11.000 | max=269.000
# episode= 343 | treward=  8.000 | max=269.000
# episode= 344 | treward=  7.000 | max=269.000
# episode= 345 | treward=270.000 | max=270.000
# episode= 346 | treward=189.000 | max=270.000
# episode= 347 | treward=108.000 | max=270.000
# episode= 348 | treward=248.000 | max=270.000
# episode= 349 | treward=181.000 | max=270.000
# episode= 350 | treward=228.000 | max=270.000
# episode= 351 | treward=  8.000 | max=270.000
# episode= 352 | treward=250.000 | max=270.000
# episode= 353 | treward= 15.000 | max=270.000
# episode= 354 | treward= 19.000 | max=270.000
# episode= 355 | treward=263.000 | max=270.000
# episode= 356 | treward=  8.000 | max=270.000
# episode= 357 | treward= 12.000 | max=270.000
# episode= 358 | treward= 12.000 | max=270.000
# episode= 359 | treward=255.000 | max=270.000
# episode= 360 | treward=257.000 | max=270.000
# episode= 361 | treward=260.000 | max=270.000
# episode= 362 | treward=  8.000 | max=270.000
# episode= 363 | treward=249.000 | max=270.000
# episode= 364 | treward=257.000 | max=270.000
# episode= 365 | treward= 46.000 | max=270.000
# episode= 366 | treward=  8.000 | max=270.000
# episode= 367 | treward=  7.000 | max=270.000
# episode= 368 | treward=143.000 | max=270.000
# episode= 369 | treward=265.000 | max=270.000
# episode= 370 | treward= 18.000 | max=270.000
# episode= 371 | treward=246.000 | max=270.000
# episode= 372 | treward=263.000 | max=270.000
# episode= 373 | treward= 23.000 | max=270.000
# episode= 374 | treward=246.000 | max=270.000
# episode= 375 | treward=133.000 | max=270.000
# episode= 376 | treward=260.000 | max=270.000
# episode= 377 | treward= 17.000 | max=270.000
# episode= 378 | treward=252.000 | max=270.000
# episode= 379 | treward=187.000 | max=270.000
# episode= 380 | treward=263.000 | max=270.000
# episode= 381 | treward=  6.000 | max=270.000
# episode= 382 | treward=  8.000 | max=270.000
# episode= 383 | treward=249.000 | max=270.000
# episode= 384 | treward=263.000 | max=270.000
# episode= 385 | treward=  6.000 | max=270.000
# episode= 386 | treward=259.000 | max=270.000
# episode= 387 | treward=  9.000 | max=270.000
# episode= 388 | treward=196.000 | max=270.000
# episode= 389 | treward= 17.000 | max=270.000
# episode= 390 | treward=277.000 | max=277.000
# episode= 391 | treward=  5.000 | max=277.000
# episode= 392 | treward=263.000 | max=277.000
# episode= 393 | treward=266.000 | max=277.000
# episode= 394 | treward=267.000 | max=277.000
# episode= 395 | treward=266.000 | max=277.000
# episode= 396 | treward=  6.000 | max=277.000
# episode= 397 | treward=243.000 | max=277.000
# episode= 398 | treward=260.000 | max=277.000
# episode= 399 | treward=248.000 | max=277.000
# episode= 400 | treward=249.000 | max=277.000
# episode= 401 | treward=261.000 | max=277.000
# episode= 402 | treward=  7.000 | max=277.000
# episode= 403 | treward=251.000 | max=277.000
# episode= 404 | treward=269.000 | max=277.000
# episode= 405 | treward=275.000 | max=277.000
# episode= 406 | treward= 21.000 | max=277.000
# episode= 407 | treward=260.000 | max=277.000
# episode= 408 | treward=136.000 | max=277.000
# episode= 409 | treward= 92.000 | max=277.000
# episode= 410 | treward=117.000 | max=277.000
# episode= 411 | treward= 18.000 | max=277.000
# episode= 412 | treward=  8.000 | max=277.000
# episode= 413 | treward=257.000 | max=277.000
# episode= 414 | treward=228.000 | max=277.000
# episode= 415 | treward= 14.000 | max=277.000
# episode= 416 | treward=275.000 | max=277.000
# episode= 417 | treward=  9.000 | max=277.000
# episode= 418 | treward=267.000 | max=277.000
# episode= 419 | treward=272.000 | max=277.000
# episode= 420 | treward=  8.000 | max=277.000
# episode= 421 | treward=255.000 | max=277.000
# episode= 422 | treward=253.000 | max=277.000
# episode= 423 | treward=250.000 | max=277.000
# episode= 424 | treward=238.000 | max=277.000
# episode= 425 | treward=246.000 | max=277.000
# episode= 426 | treward=256.000 | max=277.000
# episode= 427 | treward=264.000 | max=277.000
# episode= 428 | treward=245.000 | max=277.000
# episode= 429 | treward=177.000 | max=277.000
# episode= 430 | treward= 93.000 | max=277.000
# episode= 431 | treward=  9.000 | max=277.000
# episode= 432 | treward=250.000 | max=277.000
# episode= 433 | treward=261.000 | max=277.000
# episode= 434 | treward=249.000 | max=277.000
# episode= 435 | treward=245.000 | max=277.000
# episode= 436 | treward=187.000 | max=277.000
# episode= 437 | treward=248.000 | max=277.000
# episode= 438 | treward=257.000 | max=277.000
# episode= 439 | treward= 11.000 | max=277.000
# episode= 440 | treward=272.000 | max=277.000
# episode= 441 | treward=262.000 | max=277.000
# episode= 442 | treward=153.000 | max=277.000
# episode= 443 | treward=271.000 | max=277.000
# episode= 444 | treward=264.000 | max=277.000
# episode= 445 | treward=279.000 | max=279.000
# episode= 446 | treward=  8.000 | max=279.000
# episode= 447 | treward=250.000 | max=279.000
# episode= 448 | treward=262.000 | max=279.000
# episode= 449 | treward= 13.000 | max=279.000
# episode= 450 | treward=265.000 | max=279.000
# episode= 451 | treward=243.000 | max=279.000
# episode= 452 | treward=252.000 | max=279.000
# episode= 453 | treward= 63.000 | max=279.000
# episode= 454 | treward=  6.000 | max=279.000
# episode= 455 | treward=262.000 | max=279.000
# episode= 456 | treward=253.000 | max=279.000
# episode= 457 | treward=  7.000 | max=279.000
# episode= 458 | treward=258.000 | max=279.000
# episode= 459 | treward=267.000 | max=279.000
# episode= 460 | treward= 29.000 | max=279.000
# episode= 461 | treward=255.000 | max=279.000
# episode= 462 | treward=258.000 | max=279.000
# episode= 463 | treward=262.000 | max=279.000
# episode= 464 | treward=251.000 | max=279.000
# episode= 465 | treward=252.000 | max=279.000
# episode= 466 | treward=257.000 | max=279.000
# episode= 467 | treward=253.000 | max=279.000
# episode= 468 | treward=263.000 | max=279.000
# episode= 469 | treward=273.000 | max=279.000
# episode= 470 | treward=261.000 | max=279.000
# episode= 471 | treward=262.000 | max=279.000
# episode= 472 | treward=  6.000 | max=279.000
# episode= 473 | treward=261.000 | max=279.000
# episode= 474 | treward=269.000 | max=279.000
# episode= 475 | treward= 16.000 | max=279.000
# episode= 476 | treward=264.000 | max=279.000
# episode= 477 | treward=255.000 | max=279.000
# episode= 478 | treward=269.000 | max=279.000
# episode= 479 | treward=261.000 | max=279.000
# episode= 480 | treward=  7.000 | max=279.000
# episode= 481 | treward=269.000 | max=279.000
# episode= 482 | treward=  7.000 | max=279.000
# episode= 483 | treward= 11.000 | max=279.000
# episode= 484 | treward=271.000 | max=279.000
# episode= 485 | treward=255.000 | max=279.000
# episode= 486 | treward= 20.000 | max=279.000
# episode= 487 | treward=  6.000 | max=279.000
# episode= 488 | treward=257.000 | max=279.000
# episode= 489 | treward=250.000 | max=279.000
# episode= 490 | treward=270.000 | max=279.000
# episode= 491 | treward=247.000 | max=279.000
# episode= 492 | treward=263.000 | max=279.000
# episode= 493 | treward=269.000 | max=279.000
# episode= 494 | treward=249.000 | max=279.000
# episode= 495 | treward=253.000 | max=279.000
# episode= 496 | treward=258.000 | max=279.000
# episode= 497 | treward=256.000 | max=279.000
# episode= 498 | treward=260.000 | max=279.000
# episode= 499 | treward= 35.000 | max=279.000
# episode= 500 | treward=254.000 | max=279.000
# CPU times: total: 1min 27s
# Wall time: 2min 6s

# %%
# %%time
tradingagent.test(50, min_accuracy=0.0,
           min_performance=0.0,
           verbose=True, full=False)
# Out:
# total reward= 486 | accuracy=0.547 | performance=1.678
# CPU times: total: 19.2 s
# Wall time: 24.1 s

# %%
sum(tradingagent.performances) / len(tradingagent.performances)
# Out:
# 1.321637016492338

# %%
#plt.hist(random_performances, bins=30, color='b', label='random (left)')
#plt.hist(tradingagent.performances, bins=30, color='r', label='trained (right)')
#plt.xlabel('gross performance')
#plt.ylabel('frequency')
#plt.legend();

# %% [markdown]
# ## Synthèse et perspectives
#
# Le DQN sur ce jeu de trading offre une base pour étendre vers des modèles plus riches (processus stochastiques non-gaussiens, coûts variables). Pour une extension type rBergomi ou Deep Hedging multi-actifs, conserver la structure état-action-récompense, enrichir le générateur de prix et suivre des métriques de risque (VaR, CVaR) en plus du PnL.
